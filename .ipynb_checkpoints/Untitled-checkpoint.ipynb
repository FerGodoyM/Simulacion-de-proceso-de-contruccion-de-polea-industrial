# %%
import simpy
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Constantes de Tiempo ---
HORAS = 1/24.0  # Fracción de un día
MINUTOS = 1/(24.0 * 60.0) # Fracción de un día (para 1 minuto)
DIAS_SIMULACION = 100 # Simular por 100 días
TIEMPO_LLEGADA_PROMEDIO = 2.33 # Promedio de días ENTRE ÓRDENES

# --- Lista para registrar eventos (para Gantt) ---
eventos = []
# --- Lista para registrar resultados (para histograma) ---
datos_resumen = []

def registrar_evento(id_polea, tarea, recurso, inicio, fin):
    """Registra un evento para el diagrama de Gantt."""
    eventos.append({
        "ID_Polea": id_polea,
        "Tarea": tarea,
        "Recurso": recurso,
        "Inicio": inicio,
        "Fin": fin
    })

# --- 1. Definición de Recursos (Pools) ---
def crear_recursos(env):
    """Crea los pools de recursos basados en la entrevista."""
    return {
        # 1 persona para planos/gestión
        "planificador": simpy.Resource(env, capacity=1),
        
        # ~6 personas para corte, cilindrado, soldadura
        "soldadores": simpy.Resource(env, capacity=6),
        
        # ~10 personas para tornos (tapas, ejes, manguitos, rectificado)
        "torneros": simpy.Resource(env, capacity=10),
        
        # === CAMBIO CLAVE AQUÍ ===
        # 4 operarios en el área de vulcanizado
        "operarios_vulcanizado": simpy.Resource(env, capacity=4),
        
        # 1 máquina autoclave con capacidad promedio para 7 poleas
        "autoclave": simpy.Resource(env, capacity=7),
        # === FIN DEL CAMBIO ===
        
        # ~2 personas para armado final
        "operarios_armado": simpy.Resource(env, capacity=2)
    }

# --- 2. Sub-procesos (Tareas individuales) ---

def fase_inicial(env, id_polea, recursos):
    """Desarrollo de planos y espera de materiales."""
    # 2.1. Desarrollo de Planos (usa 1 planificador)
    with recursos["planificador"].request() as req:
        yield req
        inicio = env.now
        # 4 a 5 horas. (Usamos 4, 4.5, y 5 horas)
        t_planos = random.triangular(4*HORAS, 4.5*HORAS, 5*HORAS)
        yield env.timeout(t_planos)
    registrar_evento(id_polea, "1. Planos", "Planificador", inicio, env.now)
    
    # 2.2. Espera de Materiales (no usa recurso, solo es tiempo)
    inicio_mat = env.now
    t_materiales = random.uniform(0.8, 1.2) # min, max (días)
    yield env.timeout(t_materiales)
    registrar_evento(id_polea, "2. Espera Materiales", "Logística", inicio_mat, env.now)

def proceso_manto(env, id_polea, recursos):
    """Corte, cilindrado y soldadura longitudinal. Usa 1 soldador."""
    with recursos["soldadores"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        # 2.3. Corte Láser (ahora usa MINUTOS)
        t_corte = random.uniform(10*MINUTOS, 25*MINUTOS)
        yield env.timeout(t_corte)
        # 2.4. Cilindrado
        yield env.timeout(random.triangular(0.4, 0.5, 0.6))      
        # 2.5. Soldadura Longitudinal
        yield env.timeout(random.triangular(0.8, 1.0, 1.2))

    registrar_evento(id_polea, "3. Manto (Corte-Cil-Sold)", "Soldadores", inicio, env.now)
    
def proceso_tapas(env, id_polea, recursos, tipo_polea):
    """Mecanizado de tapas. Usa 1 tornero."""
    with recursos["torneros"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        if tipo_polea == 'grande':
            t_tapas = random.triangular(1.5, 2.0, 2.2)
        else:
            t_tapas = random.triangular(0.8, 1.0, 1.2)
        yield env.timeout(t_tapas)
    registrar_evento(id_polea, "3. Tapas (Mecanizado)", "Torneros", inicio, env.now)

def proceso_eje(env, id_polea, recursos, tipo_polea):
    """Fabricación de eje (depende del tamaño). Usa 1 tornero."""
    with recursos["torneros"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        if tipo_polea == 'grande':
            # 2 días (día y noche)
            t_eje = random.triangular(1.8, 2.0, 2.2)
        else:
            # 1 día (polea chica)
            t_eje = random.triangular(0.8, 1.0, 1.2)         
        yield env.timeout(t_eje)
    registrar_evento(id_polea, "3. Eje (Mecanizado)", "Torneros", inicio, env.now)

def proceso_manguitos(env, id_polea, recursos):
    """Fabricación de manguitos. Usa 1 tornero."""
    with recursos["torneros"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        yield env.timeout(random.triangular(0.4, 0.5, 0.6))
    registrar_evento(id_polea, "3. Manguitos (Mecanizado)", "Torneros", inicio, env.now)
    
def ensamblaje_intermedio(env, id_polea, recursos):
    """Soldar tapas y rectificar. Usa 1 soldador, luego 1 tornero."""
    # 4.1. Soldar Tapas al Manto (usa 1 soldador)
    with recursos["soldadores"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        yield env.timeout(random.triangular(4*HORAS, 5*HORAS, 6*HORAS))
    registrar_evento(id_polea, "4. Soldar Tapas", "Soldadores", inicio, env.now)
    # 4.2. Rectificado Exterior (usa 1 tornero)
    with recursos["torneros"].request() as req:
        yield req
        inicio_rect = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        yield env.timeout(random.triangular(3*HORAS, 4*HORAS, 5*HORAS))
    registrar_evento(id_polea, "5. Rectificado", "Torneros", inicio_rect, env.now)

def vulcanizado(env, id_polea, recursos):
    """Proceso completo de vulcanizado. Usa 1 operario y 1 slot de autoclave."""
    print(f"[{env.now:.2f}] Polea {id_polea}: Esperando por 1 Op. Vulcanizado y 1 Autoclave")
    with recursos["operarios_vulcanizado"].request() as req_op:
        yield req_op 
        with recursos["autoclave"].request() as req_aut:
            yield req_aut    
            inicio_proceso = env.now # Iniciar cronómetro DESPUÉS de tomar AMBOS recursos
            print(f"[{env.now:.2f}] Polea {id_polea}: Inicia Vulcanizado (con 1 op.)")
            
            t_vulcanizado = random.uniform(8*HORAS, 12*HORAS)
            yield env.timeout(t_vulcanizado) 
            fin_proceso = env.now # Registrar fin    
    # Registrar el tiempo de PROCESO real para cada recurso
    registrar_evento(id_polea, "6. Vulcanizado (Operario)", "operarios_vulcanizado", inicio_proceso, fin_proceso)
    registrar_evento(id_polea, "6. Vulcanizado (Maquina)", "autoclave", inicio_proceso, fin_proceso)
    print(f"[{env.now:.2f}] Polea {id_polea}: Termina Vulcanizado")

def armado_final(env, id_polea, recursos):
    """Ensamblaje final (Eje, Manguitos, Rodamientos). Usa 2 operarios."""
    with recursos["operarios_armado"].request() as req:
        yield req
        inicio = env.now # Iniciar cronómetro DESPUÉS de tomar el recurso
        yield env.timeout(random.triangular(0.4, 0.5, 0.6))
    registrar_evento(id_polea, "7. Armado Final", "Op. Armado", inicio, env.now)

# --- 3. Proceso Principal (Orquestador por Polea) ---

def polea_proceso(env, id_polea, recursos, datos_resumen):
    """Orquesta la fabricación completa de una polea."""
    print(f"[{env.now:.2f}] Día {int(env.now)}: Llega Orden de Polea {id_polea}")
    t_inicio_ciclo = env.now
    
    # Decide aleatoriamente el tipo de polea
    tipo_polea = random.choice(['chica', 'grande'])
    
    # 1. Fase Inicial (Secuencial)
    yield env.process(fase_inicial(env, id_polea, recursos))
    
    # 2. Fabricación Paralela de Componentes
    p_manto = env.process(proceso_manto(env, id_polea, recursos))
    p_tapas = env.process(proceso_tapas(env, id_polea, recursos, tipo_polea))
    p_eje = env.process(proceso_eje(env, id_polea, recursos, tipo_polea))
    p_manguitos = env.process(proceso_manguitos(env, id_polea, recursos))
    
    # 3. Sincronización 1: Ensamblaje Intermedio
    yield p_manto & p_tapas
    print(f"[{env.now:.2f}] Polea {id_polea}: Manto y Tapas listos. Inicia Ensamblaje Intermedio.")
    p_ensamblada = env.process(ensamblaje_intermedio(env, id_polea, recursos))
    
    # 4. Sincronización 2: Vulcanizado
    yield p_ensamblada
    print(f"[{env.now:.2f}] Polea {id_polea}: Ensamblaje listo. Pasa a Vulcanizado.")
    p_vulcanizada = env.process(vulcanizado(env, id_polea, recursos))
    
    # 5. Sincronización 3: Armado Final
    yield p_vulcanizada & p_eje & p_manguitos
    print(f"[{env.now:.2f}] Polea {id_polea}: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.")
    
    # 6. Fase Final
    yield env.process(armado_final(env, id_polea, recursos))
    
    # 7. Fin
    t_fin_ciclo = env.now
    t_total_ciclo = t_fin_ciclo - t_inicio_ciclo
    print(f"[{env.now:.2f}] Polea {id_polea} TERMINADA. Tiempo total: {t_total_ciclo:.2f} días.")
    
    # Guardar resultados
    datos_resumen.append({
        "id_polea": id_polea,
        "tipo": tipo_polea,
        "tiempo_ciclo": t_total_ciclo
    })

# --- 4. Generador de Llegadas ---

def llegada_ordenes(env, recursos, datos_resumen, id_counter):
    """Genera llegadas de nuevas ÓRDENES (lotes) de poleas."""
    
    while True:
        # 1. Espera un tiempo aleatorio para la próxima ORDEN
        t_llegada = random.expovariate(1.0 / TIEMPO_LLEGADA_PROMEDIO)
        yield env.timeout(t_llegada)

        tamano_lote = int(random.triangular(1, 2, 5))
        print(f"[{env.now:.2f}] *** Nueva ORDEN recibida. Tamaño del lote: {tamano_lote} poleas ***")

        # 3. Crea todas las poleas de ese lote al mismo tiempo
        for i in range(tamano_lote):
            id_counter[0] += 1
            env.process(polea_proceso(env, id_counter[0], recursos, datos_resumen))

# --- 5. Ejecución y Análisis ---

print("--- Iniciando Simulación de Maestranza ---")
# Creamos el entorno y los recursos ANTES de pasarlos
env = simpy.Environment()
recursos = crear_recursos(env)
id_counter = [0] # Creamos un contador
env.process(llegada_ordenes(env, recursos, datos_resumen, id_counter))
env.run(until=DIAS_SIMULACION)
print(f"--- Simulación terminada a los {DIAS_SIMULACION} días ---")

# --- 5.1. Preparación de DataFrames ---
df_resumen = pd.DataFrame(datos_resumen)
df_eventos = pd.DataFrame(eventos)

# Guardar archivos .csv (o .doe)
df_eventos.to_csv("simulacion_eventos_gantt.doe", index=False) # Guardamos como .doe
df_resumen.to_csv("simulacion_resumen_estadistico.csv", index=False)
print(f"\nArchivos 'simulacion_eventos_gantt.doe' y 'simulacion_resumen_estadistico.csv' generados")

# --- 5.2. Análisis Estadístico Básico ---
print("\n--- Resumen Estadístico de Tiempos de Ciclo (en días) ---")
print(df_resumen['tiempo_ciclo'].describe())

# --- 5.3. Gráfico 1: Histograma de Tiempos de Ciclo (Este ya lo tenías) ---
plt.figure(figsize=(10, 6))
plt.hist(df_resumen['tiempo_ciclo'], bins=20, edgecolor='black', alpha=0.7)
plt.title('Distribución de Tiempos de Ciclo de Fabricación de Poleas')
plt.xlabel('Tiempo de Ciclo (Días)')
plt.ylabel('Frecuencia (Nº de Poleas)')
plt.axvline(df_resumen['tiempo_ciclo'].mean(), color='red', linestyle='dashed', linewidth=2, label=f"Promedio: {df_resumen['tiempo_ciclo'].mean():.2f} días")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig("1_histograma_tiempos_ciclo.png")
print("Gráfico '1_histograma_tiempos_ciclo.png' generado")

# GRÁFICO 1: UTILIZACIÓN DE RECURSOS
print("Generando gráfico de utilización...")

# 1. Calcular duración de cada evento
df_eventos['Duracion'] = df_eventos['Fin'] - df_eventos['Inicio']

# 2. Agrupar por recurso y sumar el tiempo total que estuvieron ocupados
tiempo_ocupado = df_eventos.groupby('Recurso')['Duracion'].sum()

# 3. Crear un diccionario con la capacidad de cada recurso (del setup inicial)
#    Es importante que los strings coincidan con los del setup de recursos

capacidades = {
    "Planificador": 1,
    "Soldadores": 6,
    "Torneros": 10,
    "Op. Armado": 2,
    "operarios_vulcanizado": 4,
    "autoclave": 7
}
# Convertir a Series de pandas
s_capacidades = pd.Series(capacidades, name="Capacidad")

# 4. Combinar los datos de tiempo ocupado y capacidad
df_utilizacion = pd.DataFrame(tiempo_ocupado)
df_utilizacion = df_utilizacion.join(s_capacidades)

# 5. Calcular tiempo total disponible y utilización
df_utilizacion['Tiempo_Disponible'] = df_utilizacion['Capacidad'] * DIAS_SIMULACION
df_utilizacion['Utilizacion_%'] = (df_utilizacion['Duracion'] / df_utilizacion['Tiempo_Disponible']) * 100

# 6. Graficar
plt.figure(figsize=(12, 7))
ax = df_utilizacion['Utilizacion_%'].plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Utilización Promedio de Recursos (Identificación de Cuellos de Botella)', fontsize=16)
plt.ylabel('Utilización (%)')
plt.xlabel('Grupo de Recursos')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas de porcentaje sobre las barras
for p in ax.patches:
    ax.annotate(f"{p.get_height():.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 9), textcoords='offset points', fontweight='bold')

plt.tight_layout()
plt.savefig("2_grafico_utilizacion_recursos.png")
print("Gráfico '2_grafico_utilizacion_recursos.png' generado")



# --- Gráfico de Gantt---
df_gantt = df_eventos[df_eventos['ID_Polea'] <= 20]
if not df_gantt.empty:
    fig, ax = plt.subplots(figsize=(15, 8))
    
    tareas_unicas = df_gantt['Tarea'].unique()
    colors = plt.cm.tab20(np.linspace(0, 1, len(tareas_unicas)))
    color_map = dict(zip(tareas_unicas, colors))

    ax.set_yticks(df_gantt['ID_Polea'].unique())
    ax.set_ylim(0.5, 20.5) 

    for _, row in df_gantt.iterrows():
        ax.barh(
            y=row['ID_Polea'], 
            width=row['Fin'] - row['Inicio'], 
            left=row['Inicio'], 
            height=0.6,
            color=color_map[row['Tarea']],
            edgecolor='black',
            alpha=0.8
        )

    patches = [plt.Rectangle((0,0),1,1, color=color_map[tarea], label=tarea) for tarea in tareas_unicas]
    ax.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    ax.set_xlabel("Tiempo (Días)")
    ax.set_ylabel("ID de Polea")
    ax.set_title("Diagrama de Gantt - Proceso de Fabricación (Primeras 20 Poleas)")
    plt.tight_layout()
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.savefig("4_diagrama_gantt_poleas.png")
    print("Gráfico '4_diagrama_gantt_poleas.png' generado")
else:
    print("No se generaron eventos suficientes para el Gantt.")

print("\n--- ¡Análisis completo! Revisa los archivos .png generados. ---")
# Out:
# --- Iniciando Simulación de Maestranza ---
# [6.05] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [6.05] Día 6: Llega Orden de Polea 1
# [6.05] Día 6: Llega Orden de Polea 2
# [6.05] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [6.05] Día 6: Llega Orden de Polea 3
# [8.53] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [8.53] Día 8: Llega Orden de Polea 4
# [8.53] Día 8: Llega Orden de Polea 5
# [8.88] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [8.88] Día 8: Llega Orden de Polea 6
# [8.88] Día 8: Llega Orden de Polea 7
# [9.27] Polea 3: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [9.33] Polea 2: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [9.39] Polea 1: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [9.63] Polea 3: Ensamblaje listo. Pasa a Vulcanizado.
# [9.63] Polea 3: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [9.63] Polea 3: Inicia Vulcanizado (con 1 op.)
# [9.67] Polea 2: Ensamblaje listo. Pasa a Vulcanizado.
# [9.67] Polea 2: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [9.67] Polea 2: Inicia Vulcanizado (con 1 op.)
# [9.76] Polea 1: Ensamblaje listo. Pasa a Vulcanizado.
# [9.76] Polea 1: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [9.76] Polea 1: Inicia Vulcanizado (con 1 op.)
# [10.01] Polea 2: Termina Vulcanizado
# [10.01] Polea 2: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [10.08] Polea 3: Termina Vulcanizado
# [10.08] Polea 3: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [10.25] Polea 1: Termina Vulcanizado
# [10.25] Polea 1: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [10.53] Polea 3 TERMINADA. Tiempo total: 4.48 días.
# [10.54] Polea 2 TERMINADA. Tiempo total: 4.50 días.
# [11.00] Polea 1 TERMINADA. Tiempo total: 4.95 días.
# [11.16] Polea 5: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [11.45] Polea 4: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [11.53] Polea 5: Ensamblaje listo. Pasa a Vulcanizado.
# [11.53] Polea 5: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [11.53] Polea 5: Inicia Vulcanizado (con 1 op.)
# [11.82] Polea 4: Ensamblaje listo. Pasa a Vulcanizado.
# [11.82] Polea 4: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [11.82] Polea 4: Inicia Vulcanizado (con 1 op.)
# [11.87] Polea 5: Termina Vulcanizado
# [11.87] Polea 5: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [11.96] Polea 7: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [11.96] Polea 6: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [12.05] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [12.05] Día 12: Llega Orden de Polea 8
# [12.05] Día 12: Llega Orden de Polea 9
# [12.19] Polea 4: Termina Vulcanizado
# [12.19] Polea 4: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [12.30] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [12.30] Día 12: Llega Orden de Polea 10
# [12.30] Día 12: Llega Orden de Polea 11
# [12.33] Polea 6: Ensamblaje listo. Pasa a Vulcanizado.
# [12.33] Polea 6: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [12.33] Polea 6: Inicia Vulcanizado (con 1 op.)
# [12.36] Polea 7: Ensamblaje listo. Pasa a Vulcanizado.
# [12.36] Polea 7: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [12.36] Polea 7: Inicia Vulcanizado (con 1 op.)
# [12.40] Polea 5 TERMINADA. Tiempo total: 3.87 días.
# [12.72] Polea 4 TERMINADA. Tiempo total: 4.20 días.
# [12.81] Polea 6: Termina Vulcanizado
# [12.81] Polea 6: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [12.86] Polea 7: Termina Vulcanizado
# [12.86] Polea 7: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [13.32] Polea 6 TERMINADA. Tiempo total: 4.45 días.
# [13.38] Polea 7 TERMINADA. Tiempo total: 4.50 días.
# [13.77] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [13.77] Día 13: Llega Orden de Polea 12
# [14.51] Polea 8: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [14.89] Polea 8: Ensamblaje listo. Pasa a Vulcanizado.
# [14.89] Polea 8: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [14.89] Polea 8: Inicia Vulcanizado (con 1 op.)
# [15.17] Polea 10: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [15.17] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [15.17] Día 15: Llega Orden de Polea 13
# [15.17] Día 15: Llega Orden de Polea 14
# [15.34] Polea 9: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [15.39] Polea 8: Termina Vulcanizado
# [15.39] Polea 8: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [15.54] Polea 10: Ensamblaje listo. Pasa a Vulcanizado.
# [15.54] Polea 10: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [15.54] Polea 10: Inicia Vulcanizado (con 1 op.)
# [15.57] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [15.57] Día 15: Llega Orden de Polea 15
# [15.58] Polea 11: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [15.72] Polea 9: Ensamblaje listo. Pasa a Vulcanizado.
# [15.72] Polea 9: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [15.72] Polea 9: Inicia Vulcanizado (con 1 op.)
# [15.92] Polea 8 TERMINADA. Tiempo total: 3.88 días.
# [15.94] Polea 10: Termina Vulcanizado
# [15.94] Polea 10: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [15.95] Polea 11: Ensamblaje listo. Pasa a Vulcanizado.
# [15.95] Polea 11: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [15.95] Polea 11: Inicia Vulcanizado (con 1 op.)
# [16.18] Polea 9: Termina Vulcanizado
# [16.18] Polea 9: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [16.32] Polea 12: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [16.36] Polea 11: Termina Vulcanizado
# [16.36] Polea 11: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [16.38] Polea 10 TERMINADA. Tiempo total: 4.08 días.
# [16.61] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [16.61] Día 16: Llega Orden de Polea 16
# [16.61] Día 16: Llega Orden de Polea 17
# [16.67] Polea 9 TERMINADA. Tiempo total: 4.63 días.
# [16.69] Polea 12: Ensamblaje listo. Pasa a Vulcanizado.
# [16.69] Polea 12: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [16.69] Polea 12: Inicia Vulcanizado (con 1 op.)
# [16.81] Polea 11 TERMINADA. Tiempo total: 4.51 días.
# [17.06] Polea 12: Termina Vulcanizado
# [17.06] Polea 12: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [17.52] Polea 12 TERMINADA. Tiempo total: 3.75 días.
# [17.88] Polea 13: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [17.94] Polea 14: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [18.19] Polea 15: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [18.22] Polea 13: Ensamblaje listo. Pasa a Vulcanizado.
# [18.22] Polea 13: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [18.22] Polea 13: Inicia Vulcanizado (con 1 op.)
# [18.31] Polea 14: Ensamblaje listo. Pasa a Vulcanizado.
# [18.31] Polea 14: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [18.31] Polea 14: Inicia Vulcanizado (con 1 op.)
# [18.58] Polea 15: Ensamblaje listo. Pasa a Vulcanizado.
# [18.58] Polea 15: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [18.58] Polea 15: Inicia Vulcanizado (con 1 op.)
# [18.67] Polea 13: Termina Vulcanizado
# [18.67] Polea 13: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [18.77] Polea 14: Termina Vulcanizado
# [18.77] Polea 14: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [19.04] Polea 15: Termina Vulcanizado
# [19.04] Polea 15: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [19.17] Polea 13 TERMINADA. Tiempo total: 4.00 días.
# [19.30] Polea 14 TERMINADA. Tiempo total: 4.13 días.
# [19.40] Polea 16: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [19.50] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [19.50] Día 19: Llega Orden de Polea 18
# [19.50] Día 19: Llega Orden de Polea 19
# [19.65] Polea 15 TERMINADA. Tiempo total: 4.09 días.
# [19.78] Polea 16: Ensamblaje listo. Pasa a Vulcanizado.
# [19.78] Polea 16: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [19.78] Polea 16: Inicia Vulcanizado (con 1 op.)
# [20.01] Polea 17: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [20.27] Polea 16: Termina Vulcanizado
# [20.27] Polea 16: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [20.36] Polea 17: Ensamblaje listo. Pasa a Vulcanizado.
# [20.36] Polea 17: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [20.36] Polea 17: Inicia Vulcanizado (con 1 op.)
# [20.72] Polea 17: Termina Vulcanizado
# [20.72] Polea 17: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [20.79] Polea 16 TERMINADA. Tiempo total: 4.18 días.
# [21.21] Polea 17 TERMINADA. Tiempo total: 4.60 días.
# [22.66] Polea 19: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [22.76] Polea 18: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [23.02] Polea 19: Ensamblaje listo. Pasa a Vulcanizado.
# [23.02] Polea 19: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [23.02] Polea 19: Inicia Vulcanizado (con 1 op.)
# [23.11] Polea 18: Ensamblaje listo. Pasa a Vulcanizado.
# [23.11] Polea 18: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [23.11] Polea 18: Inicia Vulcanizado (con 1 op.)
# [23.48] Polea 19: Termina Vulcanizado
# [23.48] Polea 19: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [23.54] Polea 18: Termina Vulcanizado
# [23.54] Polea 18: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [23.66] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [23.66] Día 23: Llega Orden de Polea 20
# [23.66] Día 23: Llega Orden de Polea 21
# [23.95] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [23.95] Día 23: Llega Orden de Polea 22
# [23.95] Día 23: Llega Orden de Polea 23
# [24.00] Polea 19 TERMINADA. Tiempo total: 4.50 días.
# [24.00] Polea 18 TERMINADA. Tiempo total: 4.50 días.
# [24.98] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [24.98] Día 24: Llega Orden de Polea 24
# [24.98] Día 24: Llega Orden de Polea 25
# [26.56] Polea 20: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [26.62] Polea 21: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [26.70] Polea 22: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [26.93] Polea 20: Ensamblaje listo. Pasa a Vulcanizado.
# [26.93] Polea 20: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [26.93] Polea 20: Inicia Vulcanizado (con 1 op.)
# [26.95] Polea 21: Ensamblaje listo. Pasa a Vulcanizado.
# [26.95] Polea 21: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [26.95] Polea 21: Inicia Vulcanizado (con 1 op.)
# [26.98] Polea 23: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [27.06] Polea 22: Ensamblaje listo. Pasa a Vulcanizado.
# [27.06] Polea 22: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [27.06] Polea 22: Inicia Vulcanizado (con 1 op.)
# [27.33] Polea 20: Termina Vulcanizado
# [27.33] Polea 20: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [27.35] Polea 21: Termina Vulcanizado
# [27.35] Polea 21: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [27.36] Polea 23: Ensamblaje listo. Pasa a Vulcanizado.
# [27.36] Polea 23: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [27.36] Polea 23: Inicia Vulcanizado (con 1 op.)
# [27.55] Polea 22: Termina Vulcanizado
# [27.55] Polea 22: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [27.79] Polea 23: Termina Vulcanizado
# [27.79] Polea 23: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [27.85] Polea 20 TERMINADA. Tiempo total: 4.18 días.
# [27.89] Polea 21 TERMINADA. Tiempo total: 4.23 días.
# [27.92] Polea 25: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [28.09] Polea 24: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [28.30] Polea 25: Ensamblaje listo. Pasa a Vulcanizado.
# [28.30] Polea 25: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [28.30] Polea 25: Inicia Vulcanizado (con 1 op.)
# [28.34] Polea 23 TERMINADA. Tiempo total: 4.39 días.
# [28.38] Polea 22 TERMINADA. Tiempo total: 4.43 días.
# [28.45] Polea 24: Ensamblaje listo. Pasa a Vulcanizado.
# [28.45] Polea 24: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [28.45] Polea 24: Inicia Vulcanizado (con 1 op.)
# [28.68] Polea 25: Termina Vulcanizado
# [28.68] Polea 25: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [28.69] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [28.69] Día 28: Llega Orden de Polea 26
# [28.88] Polea 24: Termina Vulcanizado
# [28.88] Polea 24: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [29.21] Polea 25 TERMINADA. Tiempo total: 4.23 días.
# [29.40] Polea 24 TERMINADA. Tiempo total: 4.42 días.
# [30.30] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [30.30] Día 30: Llega Orden de Polea 27
# [30.30] Día 30: Llega Orden de Polea 28
# [31.36] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [31.36] Día 31: Llega Orden de Polea 29
# [31.88] Polea 26: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [32.10] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [32.10] Día 32: Llega Orden de Polea 30
# [32.10] Día 32: Llega Orden de Polea 31
# [32.26] Polea 26: Ensamblaje listo. Pasa a Vulcanizado.
# [32.26] Polea 26: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [32.26] Polea 26: Inicia Vulcanizado (con 1 op.)
# [32.72] Polea 26: Termina Vulcanizado
# [32.72] Polea 26: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [32.96] Polea 27: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [33.23] Polea 26 TERMINADA. Tiempo total: 4.54 días.
# [33.31] Polea 27: Ensamblaje listo. Pasa a Vulcanizado.
# [33.31] Polea 27: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [33.31] Polea 27: Inicia Vulcanizado (con 1 op.)
# [33.58] Polea 28: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [33.76] Polea 27: Termina Vulcanizado
# [33.76] Polea 27: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [33.96] Polea 28: Ensamblaje listo. Pasa a Vulcanizado.
# [33.96] Polea 28: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [33.96] Polea 28: Inicia Vulcanizado (con 1 op.)
# [34.07] Polea 29: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [34.29] Polea 27 TERMINADA. Tiempo total: 3.99 días.
# [34.29] Polea 28: Termina Vulcanizado
# [34.29] Polea 28: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [34.48] Polea 29: Ensamblaje listo. Pasa a Vulcanizado.
# [34.48] Polea 29: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [34.48] Polea 29: Inicia Vulcanizado (con 1 op.)
# [34.83] Polea 28 TERMINADA. Tiempo total: 4.53 días.
# [34.83] Polea 31: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [34.85] Polea 29: Termina Vulcanizado
# [34.85] Polea 29: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [34.86] Polea 30: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [35.22] Polea 31: Ensamblaje listo. Pasa a Vulcanizado.
# [35.22] Polea 31: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [35.22] Polea 31: Inicia Vulcanizado (con 1 op.)
# [35.24] Polea 30: Ensamblaje listo. Pasa a Vulcanizado.
# [35.24] Polea 30: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [35.24] Polea 30: Inicia Vulcanizado (con 1 op.)
# [35.28] Polea 29 TERMINADA. Tiempo total: 3.93 días.
# [35.64] Polea 31: Termina Vulcanizado
# [35.64] Polea 31: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [35.68] Polea 30: Termina Vulcanizado
# [35.68] Polea 30: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [36.17] Polea 31 TERMINADA. Tiempo total: 4.07 días.
# [36.20] Polea 30 TERMINADA. Tiempo total: 4.10 días.
# [39.45] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [39.45] Día 39: Llega Orden de Polea 32
# [41.07] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [41.07] Día 41: Llega Orden de Polea 33
# [41.07] Día 41: Llega Orden de Polea 34
# [42.22] Polea 32: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [42.58] Polea 32: Ensamblaje listo. Pasa a Vulcanizado.
# [42.58] Polea 32: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [42.58] Polea 32: Inicia Vulcanizado (con 1 op.)
# [42.99] Polea 32: Termina Vulcanizado
# [42.99] Polea 32: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [43.42] Polea 32 TERMINADA. Tiempo total: 3.97 días.
# [44.15] Polea 33: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [44.19] Polea 34: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [44.50] Polea 33: Ensamblaje listo. Pasa a Vulcanizado.
# [44.50] Polea 33: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [44.50] Polea 33: Inicia Vulcanizado (con 1 op.)
# [44.55] Polea 34: Ensamblaje listo. Pasa a Vulcanizado.
# [44.55] Polea 34: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [44.55] Polea 34: Inicia Vulcanizado (con 1 op.)
# [44.97] Polea 33: Termina Vulcanizado
# [44.97] Polea 33: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [45.04] Polea 34: Termina Vulcanizado
# [45.04] Polea 34: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [45.42] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [45.42] Día 45: Llega Orden de Polea 35
# [45.42] Día 45: Llega Orden de Polea 36
# [45.50] Polea 33 TERMINADA. Tiempo total: 4.43 días.
# [45.55] Polea 34 TERMINADA. Tiempo total: 4.48 días.
# [48.44] Polea 35: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [48.57] Polea 36: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [48.63] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [48.63] Día 48: Llega Orden de Polea 37
# [48.63] Día 48: Llega Orden de Polea 38
# [48.84] Polea 35: Ensamblaje listo. Pasa a Vulcanizado.
# [48.84] Polea 35: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [48.84] Polea 35: Inicia Vulcanizado (con 1 op.)
# [48.95] Polea 36: Ensamblaje listo. Pasa a Vulcanizado.
# [48.95] Polea 36: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [48.95] Polea 36: Inicia Vulcanizado (con 1 op.)
# [49.24] Polea 35: Termina Vulcanizado
# [49.24] Polea 35: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [49.33] Polea 36: Termina Vulcanizado
# [49.33] Polea 36: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [49.76] Polea 35 TERMINADA. Tiempo total: 4.34 días.
# [49.84] Polea 36 TERMINADA. Tiempo total: 4.42 días.
# [50.81] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [50.81] Día 50: Llega Orden de Polea 39
# [50.81] Día 50: Llega Orden de Polea 40
# [51.63] Polea 37: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [51.78] Polea 38: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [52.01] Polea 37: Ensamblaje listo. Pasa a Vulcanizado.
# [52.01] Polea 37: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [52.01] Polea 37: Inicia Vulcanizado (con 1 op.)
# [52.19] Polea 38: Ensamblaje listo. Pasa a Vulcanizado.
# [52.19] Polea 38: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [52.19] Polea 38: Inicia Vulcanizado (con 1 op.)
# [52.47] Polea 37: Termina Vulcanizado
# [52.47] Polea 37: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [52.68] Polea 38: Termina Vulcanizado
# [52.68] Polea 38: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [52.95] Polea 37 TERMINADA. Tiempo total: 4.33 días.
# [53.19] Polea 38 TERMINADA. Tiempo total: 4.56 días.
# [54.07] Polea 39: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [54.39] Polea 40: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [54.43] Polea 39: Ensamblaje listo. Pasa a Vulcanizado.
# [54.43] Polea 39: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [54.43] Polea 39: Inicia Vulcanizado (con 1 op.)
# [54.73] Polea 40: Ensamblaje listo. Pasa a Vulcanizado.
# [54.73] Polea 40: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [54.73] Polea 40: Inicia Vulcanizado (con 1 op.)
# [54.88] Polea 39: Termina Vulcanizado
# [54.88] Polea 39: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [55.18] Polea 40: Termina Vulcanizado
# [55.18] Polea 40: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [55.32] Polea 39 TERMINADA. Tiempo total: 4.51 días.
# [55.65] Polea 40 TERMINADA. Tiempo total: 4.84 días.
# [58.92] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [58.92] Día 58: Llega Orden de Polea 41
# [58.92] Día 58: Llega Orden de Polea 42
# [59.35] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [59.35] Día 59: Llega Orden de Polea 43
# [59.35] Día 59: Llega Orden de Polea 44
# [61.43] Polea 41: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [61.83] Polea 41: Ensamblaje listo. Pasa a Vulcanizado.
# [61.83] Polea 41: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [61.83] Polea 41: Inicia Vulcanizado (con 1 op.)
# [62.14] Polea 43: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [62.28] Polea 41: Termina Vulcanizado
# [62.28] Polea 41: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [62.28] Polea 42: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [62.53] Polea 43: Ensamblaje listo. Pasa a Vulcanizado.
# [62.53] Polea 43: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [62.53] Polea 43: Inicia Vulcanizado (con 1 op.)
# [62.64] Polea 42: Ensamblaje listo. Pasa a Vulcanizado.
# [62.64] Polea 42: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [62.64] Polea 42: Inicia Vulcanizado (con 1 op.)
# [62.74] Polea 44: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [62.75] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [62.75] Día 62: Llega Orden de Polea 45
# [62.75] Día 62: Llega Orden de Polea 46
# [62.78] Polea 41 TERMINADA. Tiempo total: 3.86 días.
# [62.89] Polea 43: Termina Vulcanizado
# [62.89] Polea 43: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [63.04] Polea 42: Termina Vulcanizado
# [63.04] Polea 42: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [63.12] Polea 44: Ensamblaje listo. Pasa a Vulcanizado.
# [63.12] Polea 44: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [63.12] Polea 44: Inicia Vulcanizado (con 1 op.)
# [63.34] Polea 43 TERMINADA. Tiempo total: 3.99 días.
# [63.53] Polea 42 TERMINADA. Tiempo total: 4.61 días.
# [63.55] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [63.55] Día 63: Llega Orden de Polea 47
# [63.55] Polea 44: Termina Vulcanizado
# [63.55] Polea 44: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [64.10] Polea 44 TERMINADA. Tiempo total: 4.75 días.
# [64.23] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [64.23] Día 64: Llega Orden de Polea 48
# [65.77] Polea 45: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [66.15] Polea 45: Ensamblaje listo. Pasa a Vulcanizado.
# [66.15] Polea 45: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [66.15] Polea 45: Inicia Vulcanizado (con 1 op.)
# [66.17] Polea 46: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [66.44] Polea 47: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [66.54] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [66.54] Día 66: Llega Orden de Polea 49
# [66.54] Día 66: Llega Orden de Polea 50
# [66.55] Polea 45: Termina Vulcanizado
# [66.55] Polea 45: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [66.56] Polea 46: Ensamblaje listo. Pasa a Vulcanizado.
# [66.56] Polea 46: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [66.56] Polea 46: Inicia Vulcanizado (con 1 op.)
# [66.75] Polea 47: Ensamblaje listo. Pasa a Vulcanizado.
# [66.75] Polea 47: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [66.75] Polea 47: Inicia Vulcanizado (con 1 op.)
# [66.94] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [66.94] Día 66: Llega Orden de Polea 51
# [66.97] Polea 45 TERMINADA. Tiempo total: 4.22 días.
# [66.99] Polea 46: Termina Vulcanizado
# [66.99] Polea 46: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [67.25] Polea 47: Termina Vulcanizado
# [67.25] Polea 47: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [67.34] Polea 48: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [67.51] Polea 46 TERMINADA. Tiempo total: 4.76 días.
# [67.65] Polea 48: Ensamblaje listo. Pasa a Vulcanizado.
# [67.65] Polea 48: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [67.65] Polea 48: Inicia Vulcanizado (con 1 op.)
# [67.67] Polea 47 TERMINADA. Tiempo total: 4.12 días.
# [68.11] Polea 48: Termina Vulcanizado
# [68.11] Polea 48: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [68.64] Polea 48 TERMINADA. Tiempo total: 4.41 días.
# [69.62] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [69.62] Día 69: Llega Orden de Polea 52
# [69.62] Día 69: Llega Orden de Polea 53
# [69.66] Polea 50: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [69.78] Polea 49: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [70.01] Polea 50: Ensamblaje listo. Pasa a Vulcanizado.
# [70.01] Polea 50: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [70.01] Polea 50: Inicia Vulcanizado (con 1 op.)
# [70.09] Polea 51: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [70.15] Polea 49: Ensamblaje listo. Pasa a Vulcanizado.
# [70.15] Polea 49: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [70.15] Polea 49: Inicia Vulcanizado (con 1 op.)
# [70.45] Polea 51: Ensamblaje listo. Pasa a Vulcanizado.
# [70.45] Polea 51: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [70.45] Polea 51: Inicia Vulcanizado (con 1 op.)
# [70.48] Polea 50: Termina Vulcanizado
# [70.48] Polea 50: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [70.51] Polea 49: Termina Vulcanizado
# [70.51] Polea 49: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [70.88] Polea 51: Termina Vulcanizado
# [70.88] Polea 51: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [70.90] Polea 50 TERMINADA. Tiempo total: 4.36 días.
# [70.97] Polea 49 TERMINADA. Tiempo total: 4.43 días.
# [71.41] Polea 51 TERMINADA. Tiempo total: 4.47 días.
# [71.83] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [71.83] Día 71: Llega Orden de Polea 54
# [71.83] Día 71: Llega Orden de Polea 55
# [71.98] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [71.98] Día 71: Llega Orden de Polea 56
# [72.65] Polea 53: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [72.84] Polea 52: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [73.03] Polea 53: Ensamblaje listo. Pasa a Vulcanizado.
# [73.03] Polea 53: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [73.03] Polea 53: Inicia Vulcanizado (con 1 op.)
# [73.24] Polea 52: Ensamblaje listo. Pasa a Vulcanizado.
# [73.24] Polea 52: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [73.24] Polea 52: Inicia Vulcanizado (con 1 op.)
# [73.37] Polea 53: Termina Vulcanizado
# [73.37] Polea 53: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [73.41] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [73.41] Día 73: Llega Orden de Polea 57
# [73.41] Día 73: Llega Orden de Polea 58
# [73.43] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [73.43] Día 73: Llega Orden de Polea 59
# [73.55] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [73.55] Día 73: Llega Orden de Polea 60
# [73.55] Día 73: Llega Orden de Polea 61
# [73.66] Polea 52: Termina Vulcanizado
# [73.66] Polea 52: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [73.90] Polea 53 TERMINADA. Tiempo total: 4.27 días.
# [74.18] Polea 52 TERMINADA. Tiempo total: 4.56 días.
# [74.51] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [74.51] Día 74: Llega Orden de Polea 62
# [74.51] Día 74: Llega Orden de Polea 63
# [74.99] Polea 54: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [75.01] Polea 56: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [75.46] Polea 55: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [75.62] Polea 54: Ensamblaje listo. Pasa a Vulcanizado.
# [75.62] Polea 54: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [75.62] Polea 54: Inicia Vulcanizado (con 1 op.)
# [75.72] Polea 56: Ensamblaje listo. Pasa a Vulcanizado.
# [75.72] Polea 56: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [75.72] Polea 56: Inicia Vulcanizado (con 1 op.)
# [76.07] Polea 54: Termina Vulcanizado
# [76.07] Polea 54: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [76.07] Polea 56: Termina Vulcanizado
# [76.07] Polea 56: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [76.11] Polea 58: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [76.47] Polea 57: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [76.52] Polea 54 TERMINADA. Tiempo total: 4.69 días.
# [76.55] Polea 56 TERMINADA. Tiempo total: 4.57 días.
# [76.66] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [76.66] Día 76: Llega Orden de Polea 64
# [76.70] Polea 55: Ensamblaje listo. Pasa a Vulcanizado.
# [76.70] Polea 55: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [76.70] Polea 55: Inicia Vulcanizado (con 1 op.)
# [76.75] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [76.75] Día 76: Llega Orden de Polea 65
# [76.87] Polea 61: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [76.97] Polea 59: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [77.00] Polea 60: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [77.10] Polea 58: Ensamblaje listo. Pasa a Vulcanizado.
# [77.10] Polea 58: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.10] Polea 58: Inicia Vulcanizado (con 1 op.)
# [77.12] Polea 55: Termina Vulcanizado
# [77.12] Polea 55: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.13] Polea 57: Ensamblaje listo. Pasa a Vulcanizado.
# [77.13] Polea 57: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.13] Polea 57: Inicia Vulcanizado (con 1 op.)
# [77.18] Polea 62: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [77.26] Polea 61: Ensamblaje listo. Pasa a Vulcanizado.
# [77.26] Polea 61: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.26] Polea 61: Inicia Vulcanizado (con 1 op.)
# [77.35] Polea 59: Ensamblaje listo. Pasa a Vulcanizado.
# [77.35] Polea 59: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.35] Polea 59: Inicia Vulcanizado (con 1 op.)
# [77.38] Polea 60: Ensamblaje listo. Pasa a Vulcanizado.
# [77.38] Polea 60: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.51] Polea 58: Termina Vulcanizado
# [77.51] Polea 60: Inicia Vulcanizado (con 1 op.)
# [77.51] Polea 58: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.52] Polea 62: Ensamblaje listo. Pasa a Vulcanizado.
# [77.52] Polea 62: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [77.57] Polea 57: Termina Vulcanizado
# [77.57] Polea 62: Inicia Vulcanizado (con 1 op.)
# [77.57] Polea 57: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.63] Polea 55 TERMINADA. Tiempo total: 5.80 días.
# [77.69] Polea 61: Termina Vulcanizado
# [77.69] Polea 61: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.71] Polea 59: Termina Vulcanizado
# [77.71] Polea 59: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.87] Polea 60: Termina Vulcanizado
# [77.87] Polea 60: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [77.95] Polea 58 TERMINADA. Tiempo total: 4.55 días.
# [78.01] Polea 62: Termina Vulcanizado
# [78.01] Polea 62: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [78.12] Polea 57 TERMINADA. Tiempo total: 4.71 días.
# [78.40] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [78.40] Día 78: Llega Orden de Polea 66
# [78.40] Día 78: Llega Orden de Polea 67
# [78.48] Polea 61 TERMINADA. Tiempo total: 4.93 días.
# [78.60] Polea 59 TERMINADA. Tiempo total: 5.17 días.
# [78.61] Polea 63: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [78.96] Polea 60 TERMINADA. Tiempo total: 5.41 días.
# [78.99] Polea 63: Ensamblaje listo. Pasa a Vulcanizado.
# [78.99] Polea 63: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [78.99] Polea 63: Inicia Vulcanizado (con 1 op.)
# [79.10] Polea 62 TERMINADA. Tiempo total: 4.60 días.
# [79.17] Polea 64: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [79.42] Polea 63: Termina Vulcanizado
# [79.42] Polea 63: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [79.52] Polea 64: Ensamblaje listo. Pasa a Vulcanizado.
# [79.52] Polea 64: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [79.52] Polea 64: Inicia Vulcanizado (con 1 op.)
# [79.88] Polea 65: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [79.91] Polea 63 TERMINADA. Tiempo total: 5.41 días.
# [79.95] Polea 64: Termina Vulcanizado
# [79.95] Polea 64: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [79.96] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [79.96] Día 79: Llega Orden de Polea 68
# [80.26] Polea 65: Ensamblaje listo. Pasa a Vulcanizado.
# [80.26] Polea 65: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [80.26] Polea 65: Inicia Vulcanizado (con 1 op.)
# [80.37] Polea 64 TERMINADA. Tiempo total: 3.71 días.
# [80.51] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [80.51] Día 80: Llega Orden de Polea 69
# [80.51] Día 80: Llega Orden de Polea 70
# [80.67] Polea 65: Termina Vulcanizado
# [80.67] Polea 65: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [81.10] Polea 65 TERMINADA. Tiempo total: 4.35 días.
# [81.42] Polea 66: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [81.69] Polea 67: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [81.78] Polea 66: Ensamblaje listo. Pasa a Vulcanizado.
# [81.78] Polea 66: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [81.78] Polea 66: Inicia Vulcanizado (con 1 op.)
# [82.03] Polea 67: Ensamblaje listo. Pasa a Vulcanizado.
# [82.03] Polea 67: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [82.03] Polea 67: Inicia Vulcanizado (con 1 op.)
# [82.18] Polea 66: Termina Vulcanizado
# [82.18] Polea 66: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [82.41] Polea 67: Termina Vulcanizado
# [82.41] Polea 67: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [82.49] Polea 68: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [82.69] Polea 66 TERMINADA. Tiempo total: 4.29 días.
# [82.85] Polea 68: Ensamblaje listo. Pasa a Vulcanizado.
# [82.85] Polea 68: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [82.85] Polea 68: Inicia Vulcanizado (con 1 op.)
# [82.86] Polea 69: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [82.92] Polea 67 TERMINADA. Tiempo total: 4.52 días.
# [83.14] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [83.14] Día 83: Llega Orden de Polea 71
# [83.14] Día 83: Llega Orden de Polea 72
# [83.23] Polea 69: Ensamblaje listo. Pasa a Vulcanizado.
# [83.23] Polea 69: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [83.23] Polea 69: Inicia Vulcanizado (con 1 op.)
# [83.29] Polea 68: Termina Vulcanizado
# [83.29] Polea 68: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [83.65] Polea 70: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [83.67] Polea 69: Termina Vulcanizado
# [83.67] Polea 69: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [83.78] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [83.78] Día 83: Llega Orden de Polea 73
# [83.82] Polea 68 TERMINADA. Tiempo total: 3.86 días.
# [84.04] Polea 70: Ensamblaje listo. Pasa a Vulcanizado.
# [84.04] Polea 70: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [84.04] Polea 70: Inicia Vulcanizado (con 1 op.)
# [84.21] Polea 69 TERMINADA. Tiempo total: 3.70 días.
# [84.23] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [84.23] Día 84: Llega Orden de Polea 74
# [84.23] Día 84: Llega Orden de Polea 75
# [84.51] Polea 70: Termina Vulcanizado
# [84.51] Polea 70: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [84.72] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [84.72] Día 84: Llega Orden de Polea 76
# [84.72] Día 84: Llega Orden de Polea 77
# [85.00] Polea 70 TERMINADA. Tiempo total: 4.49 días.
# [85.07] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [85.07] Día 85: Llega Orden de Polea 78
# [85.07] Día 85: Llega Orden de Polea 79
# [85.60] Polea 71: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [85.82] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [85.82] Día 85: Llega Orden de Polea 80
# [85.82] Día 85: Llega Orden de Polea 81
# [86.07] Polea 72: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [86.22] Polea 71: Ensamblaje listo. Pasa a Vulcanizado.
# [86.22] Polea 71: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [86.22] Polea 71: Inicia Vulcanizado (con 1 op.)
# [86.50] Polea 73: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [86.69] Polea 71: Termina Vulcanizado
# [86.69] Polea 71: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [87.12] Polea 75: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [87.17] Polea 72: Ensamblaje listo. Pasa a Vulcanizado.
# [87.17] Polea 72: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [87.17] Polea 72: Inicia Vulcanizado (con 1 op.)
# [87.23] Polea 71 TERMINADA. Tiempo total: 4.09 días.
# [87.36] Polea 77: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [87.39] Polea 74: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [87.58] Polea 72: Termina Vulcanizado
# [87.58] Polea 72: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [87.84] Polea 76: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [87.95] Polea 73: Ensamblaje listo. Pasa a Vulcanizado.
# [87.95] Polea 73: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [87.95] Polea 73: Inicia Vulcanizado (con 1 op.)
# [88.10] Polea 77: Ensamblaje listo. Pasa a Vulcanizado.
# [88.10] Polea 77: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.10] Polea 77: Inicia Vulcanizado (con 1 op.)
# [88.11] Polea 72 TERMINADA. Tiempo total: 4.97 días.
# [88.13] Polea 79: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [88.26] Polea 75: Ensamblaje listo. Pasa a Vulcanizado.
# [88.26] Polea 75: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.26] Polea 75: Inicia Vulcanizado (con 1 op.)
# [88.31] Polea 74: Ensamblaje listo. Pasa a Vulcanizado.
# [88.31] Polea 74: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.31] Polea 74: Inicia Vulcanizado (con 1 op.)
# [88.32] Polea 76: Ensamblaje listo. Pasa a Vulcanizado.
# [88.32] Polea 76: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.36] Polea 73: Termina Vulcanizado
# [88.36] Polea 76: Inicia Vulcanizado (con 1 op.)
# [88.36] Polea 73: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [88.47] Polea 78: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [88.48] Polea 79: Ensamblaje listo. Pasa a Vulcanizado.
# [88.48] Polea 79: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.57] Polea 77: Termina Vulcanizado
# [88.57] Polea 79: Inicia Vulcanizado (con 1 op.)
# [88.57] Polea 77: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [88.67] Polea 74: Termina Vulcanizado
# [88.67] Polea 74: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [88.72] Polea 76: Termina Vulcanizado
# [88.72] Polea 76: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [88.74] Polea 75: Termina Vulcanizado
# [88.74] Polea 75: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [88.84] Polea 78: Ensamblaje listo. Pasa a Vulcanizado.
# [88.84] Polea 78: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [88.84] Polea 78: Inicia Vulcanizado (con 1 op.)
# [88.84] Polea 73 TERMINADA. Tiempo total: 5.07 días.
# [88.87] Polea 80: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [89.03] Polea 79: Termina Vulcanizado
# [89.03] Polea 79: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [89.10] Polea 77 TERMINADA. Tiempo total: 4.38 días.
# [89.18] Polea 78: Termina Vulcanizado
# [89.18] Polea 78: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [89.23] Polea 80: Ensamblaje listo. Pasa a Vulcanizado.
# [89.23] Polea 80: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [89.23] Polea 80: Inicia Vulcanizado (con 1 op.)
# [89.36] Polea 74 TERMINADA. Tiempo total: 5.13 días.
# [89.37] Polea 81: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [89.59] Polea 80: Termina Vulcanizado
# [89.59] Polea 80: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [89.62] Polea 76 TERMINADA. Tiempo total: 4.90 días.
# [89.68] Polea 81: Ensamblaje listo. Pasa a Vulcanizado.
# [89.68] Polea 81: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [89.68] Polea 81: Inicia Vulcanizado (con 1 op.)
# [89.89] Polea 75 TERMINADA. Tiempo total: 5.67 días.
# [90.02] Polea 81: Termina Vulcanizado
# [90.02] Polea 81: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [90.15] Polea 79 TERMINADA. Tiempo total: 5.07 días.
# [90.34] Polea 78 TERMINADA. Tiempo total: 5.27 días.
# [90.62] Polea 80 TERMINADA. Tiempo total: 4.80 días.
# [90.79] Polea 81 TERMINADA. Tiempo total: 4.97 días.
# [91.11] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [91.11] Día 91: Llega Orden de Polea 82
# [91.11] Día 91: Llega Orden de Polea 83
# [93.78] Polea 82: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [94.11] Polea 82: Ensamblaje listo. Pasa a Vulcanizado.
# [94.11] Polea 82: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [94.11] Polea 82: Inicia Vulcanizado (con 1 op.)
# [94.16] Polea 83: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [94.46] Polea 82: Termina Vulcanizado
# [94.46] Polea 82: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [94.54] Polea 83: Ensamblaje listo. Pasa a Vulcanizado.
# [94.54] Polea 83: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [94.54] Polea 83: Inicia Vulcanizado (con 1 op.)
# [94.92] Polea 82 TERMINADA. Tiempo total: 3.81 días.
# [95.02] Polea 83: Termina Vulcanizado
# [95.02] Polea 83: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [95.49] Polea 83 TERMINADA. Tiempo total: 4.38 días.
# [96.21] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [96.21] Día 96: Llega Orden de Polea 84
# [98.50] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [98.50] Día 98: Llega Orden de Polea 85
# [98.50] Día 98: Llega Orden de Polea 86
# [98.67] Polea 84: Manto y Tapas listos. Inicia Ensamblaje Intermedio.
# [99.02] Polea 84: Ensamblaje listo. Pasa a Vulcanizado.
# [99.02] Polea 84: Esperando por 1 Op. Vulcanizado y 1 Autoclave
# [99.02] Polea 84: Inicia Vulcanizado (con 1 op.)
# [99.46] Polea 84: Termina Vulcanizado
# [99.46] Polea 84: Vulcanizada, Eje y Manguitos listos. Inicia Armado Final.
# [99.61] *** Nueva ORDEN recibida. Tamaño del lote: 2 poleas ***
# [99.61] Día 99: Llega Orden de Polea 87
# [99.61] Día 99: Llega Orden de Polea 88
# [99.72] *** Nueva ORDEN recibida. Tamaño del lote: 1 poleas ***
# [99.72] Día 99: Llega Orden de Polea 89
# [99.91] Polea 84 TERMINADA. Tiempo total: 3.71 días.
# --- Simulación terminada a los 100 días ---
#
# Archivos 'simulacion_eventos_gantt.doe' y 'simulacion_resumen_estadistico.csv' generados
#
# --- Resumen Estadístico de Tiempos de Ciclo (en días) ---
# count    84.000000
# mean      4.457860
# std       0.438916
# min       3.696602
# 25%       4.169298
# 50%       4.438926
# 75%       4.617557
# max       5.802978
# Name: tiempo_ciclo, dtype: float64
# Gráfico '1_histograma_tiempos_ciclo.png' generado
# Generando gráfico de utilización...
# Gráfico '2_grafico_utilizacion_recursos.png' generado
# Gráfico '4_diagrama_gantt_poleas.png' generado
#
# --- ¡Análisis completo! Revisa los archivos .png generados. ---
